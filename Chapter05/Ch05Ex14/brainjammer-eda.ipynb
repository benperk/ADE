# %%
import pandas as pd
df = spark.read.option("header", "true").parquet(
    "wasbs://brainjammer@csharpguitaradeblob.blob.core.windows.net/transformedBrainwavesV1.parquet")
pdf = df.select(df.SCENARIO, df.ELECTRODE, df.FREQUENCY, 
                df.VALUE.cast('float')).toPandas()
print(pdf.head())
print(pdf.tail())

# %%
pdf.shape

# %%
pdf.info()

# %%
pdf.describe()

# %%
df = spark.read.option("header", "true").parquet("wasbs://brainjammer@csharpguitaradeblob.blob.core.windows.net/NormalizedBrainwavesSE.parquet")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = spark.read.option("header", "true").parquet("wasbs://brainjammer@csharpguitaradeblob.blob.core.windows.net/NormalizedBrainwavesSE.parquet")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
