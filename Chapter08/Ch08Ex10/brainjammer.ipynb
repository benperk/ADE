# %%
rawReadings = "abfss://brainjammer@csharpguitar.dfs.core.windows.net/*.parquet"
rawReadingsDF = spark.read.option("header","true").parquet(rawReadings)
rawReadingsDF.createOrReplaceTempView("TmpREADING")
spark.sql("SELECT * FROM TmpREADING").limit(5).show()
# Out:
# +--------------+---------+---------+------------------+------------------+------+------------------+------------------+--------------+------------------+---------------+-------------+-----------------+--------------+
# |      SCENARIO|FREQUENCY|  AVERAGE|       STANDARDDEV|          VARIANCE|MEDIAN|        SQUAREROOT|           SQUARED|AVERAGE_Scaled|STANDARDDEV_Scaled|VARIANCE_Scaled|MEDIAN_Scaled|SQUAREROOT_Scaled|SQUARED_Scaled|
# +--------------+---------+---------+------------------+------------------+------+------------------+------------------+--------------+------------------+---------------+-------------+-----------------+--------------+
# |ClassicalMusic|    ALPHA| 7.778113|24.411291008737503| 595.9111287132685| 2.711|1.6465114636709943| 7.349520999999999|         0.208|             0.417|          0.218|         0.49|            0.608|         0.291|
# |ClassicalMusic|   BETA_H| 4.723859| 24.81640689117662| 615.8540509884384| 1.179|1.0858176642512314|          1.390041|         0.103|             0.426|          0.226|         0.14|            0.227|         0.044|
# |ClassicalMusic|   BETA_L| 5.737317|26.641458348368396|  709.767302927848| 1.889|1.3744089638822936|          3.568321|         0.138|             0.465|          0.262|        0.302|            0.423|         0.134|
# |ClassicalMusic|    GAMMA| 2.951795|  14.8998607352252|222.00584992910566| 0.737|0.8584870412533901|          0.543169|         0.043|             0.211|          0.075|        0.039|            0.073|         0.009|
# |ClassicalMusic|    THETA|24.427348| 44.34562629700377| 1966.534571673512| 3.564| 1.887855926706273|12.702096000000001|         0.777|             0.848|          0.743|        0.684|            0.771|         0.512|
# +--------------+---------+---------+------------------+------------------+------+------------------+------------------+--------------+------------------+---------------+-------------+-----------------+--------------+
